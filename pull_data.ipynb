# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Overview
# - chill dashboard for football data
# - so far will analyse players and their market values
# - data source: https://www.kaggle.com/datasets/davidcariboo/player-scores?resource=download&select=competitions.csv

# %%
competitions = pd.read_csv("data/competitions.csv")
competitions.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code confederation  \
# 0          75        Italy                  IT1        europa
# 1         122  Netherlands                  NL1        europa
# 2          56       Greece                  GR1        europa
# 3         136     Portugal                  PO1        europa
# 4         141       Russia                  RU1        europa
#
#                                                  url  is_major_national_league
# 0  https://www.transfermarkt.co.uk/italy-cup/star...                     False
# 1  https://www.transfermarkt.co.uk/johan-cruijff-...                     False
# 2  https://www.transfermarkt.co.uk/kypello-ellada...                     False
# 3  https://www.transfermarkt.co.uk/supertaca-cand...                     False
# 4  https://www.transfermarkt.co.uk/russian-super-...                     False

# %%
interest = competitions[competitions.is_major_national_league==True].competition_id.unique().tolist()

# %%
clubs = pd.read_csv("data/clubs.csv")
clubs_of_int = clubs[clubs.domestic_competition_id.isin(interest)]
clubs_of_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 173 entries, 0 to 438
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  173 non-null    int64
#  1   club_code                173 non-null    object
#  2   name                     173 non-null    object
#  3   domestic_competition_id  173 non-null    object
#  4   total_market_value       0 non-null      float64
#  5   squad_size               173 non-null    int64
#  6   average_age              172 non-null    float64
#  7   foreigners_number        173 non-null    int64
#  8   foreigners_percentage    172 non-null    float64
#  9   national_team_players    173 non-null    int64
#  10  stadium_name             173 non-null    object
#  11  stadium_seats            173 non-null    int64
#  12  net_transfer_record      173 non-null    object
#  13  coach_name               0 non-null      float64
#  14  last_season              173 non-null    int64
#  15  filename                 173 non-null    object
#  16  url                      173 non-null    object
# dtypes: float64(4), int64(6), object(7)
# memory usage: 24.3+ KB

# %%
competitions[competitions.is_major_national_league==True]
# Out:
#    competition_id competition_code            name    sub_type  \
# 9             ES1           laliga          laliga  first_tier
# 10            FR1          ligue-1         ligue-1  first_tier
# 11            IT1          serie-a         serie-a  first_tier
# 16            GB1   premier-league  premier-league  first_tier
# 33             L1       bundesliga      bundesliga  first_tier
#
#                type  country_id country_name domestic_league_code  \
# 9   domestic_league         157        Spain                  ES1
# 10  domestic_league          50       France                  FR1
# 11  domestic_league          75        Italy                  IT1
# 16  domestic_league         189      England                  GB1
# 33  domestic_league          40      Germany                   L1
#
#    confederation                                                url  \
# 9         europa  https://www.transfermarkt.co.uk/laliga/startse...
# 10        europa  https://www.transfermarkt.co.uk/ligue-1/starts...
# 11        europa  https://www.transfermarkt.co.uk/serie-a/starts...
# 16        europa  https://www.transfermarkt.co.uk/premier-league...
# 33        europa  https://www.transfermarkt.co.uk/bundesliga/sta...
#
#     is_major_national_league
# 9                       True
# 10                      True
# 11                      True
# 16                      True
# 33                      True

# %%
sel = ['competition_id', 'competition_code', 'country_name']
clubs_of_int = clubs_of_int.merge(competitions[sel], how='left', left_on='domestic_competition_id', right_on='competition_id')

# %%
del competitions, clubs, interest

# %%
players = pd.read_csv("data/players.csv")
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32601 entries, 0 to 32600
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             32601 non-null  int64
#  1   first_name                            30539 non-null  object
#  2   last_name                             32601 non-null  object
#  3   name                                  32601 non-null  object
#  4   last_season                           32601 non-null  int64
#  5   current_club_id                       32601 non-null  int64
#  6   player_code                           32601 non-null  object
#  7   country_of_birth                      29802 non-null  object
#  8   city_of_birth                         30146 non-null  object
#  9   country_of_citizenship                32218 non-null  object
#  10  date_of_birth                         32554 non-null  object
#  11  sub_position                          32421 non-null  object
#  12  position                              32601 non-null  object
#  13  foot                                  30065 non-null  object
#  14  height_in_cm                          30345 non-null  float64
#  15  contract_expiration_date              20510 non-null  object
#  16  agent_name                            16582 non-null  object
#  17  image_url                             32601 non-null  object
#  18  url                                   32601 non-null  object
#  19  current_club_domestic_competition_id  32601 non-null  object
#  20  current_club_name                     32601 non-null  object
#  21  market_value_in_eur                   31078 non-null  float64
#  22  highest_market_value_in_eur           31078 non-null  float64
# dtypes: float64(3), int64(3), object(17)
# memory usage: 5.7+ MB

# %%
interest = clubs_of_int.club_id.tolist()
players = players[(players.current_club_id.isin(interest))]

# %% [markdown]
# ## Create the main table to analyse
# 1. clubs_of_int
# 2. players
#
# - players (current_club_id) left join clubs_of_int (club_id)

# %%
# cleaning on the clubs data
print(clubs_of_int.columns)
clubs_of_int.sample(5)
# Out:
# Index(['club_id', 'club_code', 'name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'last_season',
#        'filename', 'url', 'competition_id', 'competition_code',
#        'country_name'],
#       dtype='object')
#      club_id             club_code                            name  \
# 16         4         1-fc-nurnberg                  1.FC Nuremberg
# 6        603          cardiff-city                    Cardiff City
# 120        3             1-fc-koln                       1.FC Köln
# 25      2036  1-fc-heidenheim-1846  1. Fußballclub Heidenheim 1846
# 149     1210            as-livorno                 US Livorno 1915
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# 16                       L1                 NaN          33         25.2
# 6                       GB1                 NaN          28         25.5
# 120                      L1                 NaN          34         24.6
# 25                       L1                 NaN          28         26.9
# 149                     IT1                 NaN          29         24.1
#
#      foreigners_number  foreigners_percentage  national_team_players  \
# 16                   7                   21.2                      2
# 6                   24                   85.7                      8
# 120                 11                   32.4                      6
# 25                   4                   14.3                      1
# 149                  5                   17.2                      0
#
#              stadium_name  stadium_seats net_transfer_record  coach_name  \
# 16    Max-Morlock-Stadion          50000             +€2.63m         NaN
# 6    Cardiff City Stadium          33280              €-655k         NaN
# 120   RheinEnergieSTADION          50000             +€1.60m         NaN
# 25            Voith-Arena          15000             +€7.45m         NaN
# 149        Armando Picchi          19238                 +-0         NaN
#
#      last_season                                           filename  \
# 16          2018  ../data/raw/transfermarkt-scraper/2018/clubs.j...
# 6           2018  ../data/raw/transfermarkt-scraper/2018/clubs.j...
# 120         2023  ../data/raw/transfermarkt-scraper/2023/clubs.j...
# 25          2024  ../data/raw/transfermarkt-scraper/2024/clubs.j...
# 149         2013  ../data/raw/transfermarkt-scraper/2013/clubs.j...
#
#                                                    url competition_id  \
# 16   https://www.transfermarkt.co.uk/1-fc-nurnberg/...             L1
# 6    https://www.transfermarkt.co.uk/cardiff-city/s...            GB1
# 120  https://www.transfermarkt.co.uk/1-fc-koln/star...             L1
# 25   https://www.transfermarkt.co.uk/1-fc-heidenhei...             L1
# 149  https://www.transfermarkt.co.uk/as-livorno/sta...            IT1
#
#     competition_code country_name
# 16        bundesliga      Germany
# 6     premier-league      England
# 120       bundesliga      Germany
# 25        bundesliga      Germany
# 149          serie-a        Italy

# %%
club_join = [
    'club_id', 'country_name'
]
players = players.merge(clubs_of_int[club_join], how='left', left_on='current_club_id', right_on='club_id').drop(['club_id'], axis=1)

# %%
players = players.rename({'country_name': 'country_league'}, axis=1)

# %%
cur_players = players[players.last_season==2024]
team_mv = cur_players.groupby(['current_club_id'])['market_value_in_eur'].sum()
team_mv = pd.DataFrame(team_mv).reset_index().rename({'market_value_in_eur': 'total_market_value'}, axis=1)

club_drop = [
    'total_market_value', 'coach_name'
]

clubs_of_int = clubs_of_int.drop(club_drop, axis=1)
clubs_of_int = clubs_of_int.merge(team_mv, how='left', left_on='club_id', right_on='current_club_id').drop(['current_club_id'], axis=1)

# %%
# Extract Net Transfer info
clubs_of_int.loc[:, 'net_transfer_sign'] = clubs_of_int.net_transfer_record.str.extract(r"([+-])", expand=False)
clubs_of_int.loc[:, 'net_transfer_value'] = clubs_of_int.net_transfer_record.str.extract(r"([0-9]+(?:\.[0-9]+)?)", expand=False).astype(float)

# %%
def calculate_net_transfer(row):
    if row['net_transfer_sign'] == "-":
        return row['net_transfer_value'] * -1.0
    else:
        return row['net_transfer_value'] * 1.0

clubs_of_int.loc[:, 'net_transfer_Mil'] = clubs_of_int.apply(calculate_net_transfer, axis=1)

# %% [markdown]
# # Analysis: Players

# %%
# 11,698 for players in Big 5 Leagues (All)
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11698 entries, 0 to 11697
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             11698 non-null  int64
#  1   first_name                            11252 non-null  object
#  2   last_name                             11698 non-null  object
#  3   name                                  11698 non-null  object
#  4   last_season                           11698 non-null  int64
#  5   current_club_id                       11698 non-null  int64
#  6   player_code                           11698 non-null  object
#  7   country_of_birth                      11207 non-null  object
#  8   city_of_birth                         11320 non-null  object
#  9   country_of_citizenship                11573 non-null  object
#  10  date_of_birth                         11675 non-null  object
#  11  sub_position                          11666 non-null  object
#  12  position                              11698 non-null  object
#  13  foot                                  10933 non-null  object
#  14  height_in_cm                          10965 non-null  float64
#  15  contract_expiration_date              7738 non-null   object
#  16  agent_name                            6820 non-null   object
#  17  image_url                             11698 non-null  object
#  18  url                                   11698 non-null  object
#  19  current_club_domestic_competition_id  11698 non-null  object
#  20  current_club_name                     11698 non-null  object
#  21  market_value_in_eur                   11309 non-null  float64
#  22  highest_market_value_in_eur           11309 non-null  float64
#  23  country_league                        11698 non-null  object
# dtypes: float64(3), int64(3), object(18)
# memory usage: 2.1+ MB

# %% [markdown]
# The data seems to be quite complete. Just a few things to check:
# 1. missing market_value
# 2. height_in_cm
#
# **Conclusion**
# <br>
# It's possible not to have these data, just meaning this player is too rare to be rated. :)

# %%
players[players.market_value_in_eur.isna()]
players[players.height_in_cm.isna()]
# Out:
#        player_id first_name last_name                name  last_season  \
# 6946       85316     Kilian    Falcón       Kilian Falcón         2012
# 6949       85326      Yeray     Gómez         Yeray Gómez         2014
# 8710      121232     Callum    Driver       Callum Driver         2013
# 9029      126555     Victor     Fuchs        Victor Fuchs         2012
# 9108      127185      Kévin    Crépel        Kévin Crépel         2012
# ...          ...        ...       ...                 ...          ...
# 32499    1210422  Aboubacar  Bassinga  Aboubacar Bassinga         2023
# 32504    1222050      Rocco   Di Vico       Rocco Di Vico         2023
# 32507    1225825  Christian  Chigozie  Christian Chigozie         2023
# 32521    1237073     Lander     Emery        Lander Emery         2023
# 32526    1238800      Glenn    Ngosso        Glenn Ngosso         2024
#
#        current_club_id         player_code country_of_birth  \
# 6946               142       kilian-falcon            Spain
# 6949              3302         yeray-gomez            Spain
# 8710               379       callum-driver          England
# 9029               681        victor-fuchs           France
# 9108              1159        kevin-crepel           France
# ...                ...                 ...              ...
# 32499              472  aboubacar-bassinga              NaN
# 32504              380       rocco-di-vico              NaN
# 32507             1031  christian-chigozie              NaN
# 32521              405        lander-emery              NaN
# 32526              969        glenn-ngosso         Cameroon
#
#                     city_of_birth country_of_citizenship  ...   foot  \
# 6946   Las Palmas de Gran Canaria                  Spain  ...    NaN
# 6949                        Selva                  Spain  ...    NaN
# 8710                       London                England  ...  right
# 9029                     Arcachon                 France  ...  right
# 9108                  Armentières                 France  ...  right
# ...                           ...                    ...  ...    ...
# 32499                         NaN          Cote d'Ivoire  ...    NaN
# 32504                         NaN                  Italy  ...    NaN
# 32507                         NaN                England  ...    NaN
# 32521                         NaN                  Spain  ...    NaN
# 32526                      Douala               Cameroon  ...    NaN
#
#       height_in_cm contract_expiration_date          agent_name  \
# 6946         184.0                      NaN                 NaN
# 6949         192.0                      NaN                 NaN
# 8710         173.0                      NaN                 NaN
# 9029         174.0                      NaN                 NaN
# 9108         195.0                      NaN                 NaN
# ...            ...                      ...                 ...
# 32499          NaN                      NaN  Gesport Espizua SL
# 32504          NaN                      NaN                 NaN
# 32507          NaN                      NaN                 NaN
# 32521          NaN                      NaN         MYSPORTDEAL
# 32526          NaN                      NaN                 NaN
#
#                                                image_url  \
# 6946   https://img.a.transfermarkt.technology/portrai...
# 6949   https://img.a.transfermarkt.technology/portrai...
# 8710   https://img.a.transfermarkt.technology/portrai...
# 9029   https://img.a.transfermarkt.technology/portrai...
# 9108   https://img.a.transfermarkt.technology/portrai...
# ...                                                  ...
# 32499  https://img.a.transfermarkt.technology/portrai...
# 32504  https://img.a.transfermarkt.technology/portrai...
# 32507  https://img.a.transfermarkt.technology/portrai...
# 32521  https://img.a.transfermarkt.technology/portrai...
# 32526  https://img.a.transfermarkt.technology/portrai...
#
#                                                      url  \
# 6946   https://www.transfermarkt.co.uk/kilian-falcon/...
# 6949   https://www.transfermarkt.co.uk/yeray-gomez/pr...
# 8710   https://www.transfermarkt.co.uk/callum-driver/...
# 9029   https://www.transfermarkt.co.uk/victor-fuchs/p...
# 9108   https://www.transfermarkt.co.uk/kevin-crepel/p...
# ...                                                  ...
# 32499  https://www.transfermarkt.co.uk/aboubacar-bass...
# 32504  https://www.transfermarkt.co.uk/rocco-di-vico/...
# 32507  https://www.transfermarkt.co.uk/christian-chig...
# 32521  https://www.transfermarkt.co.uk/lander-emery/p...
# 32526  https://www.transfermarkt.co.uk/glenn-ngosso/p...
#
#       current_club_domestic_competition_id                  current_club_name  \
# 6946                                   ES1                      Real Zaragoza
# 6949                                   ES1                         UD Almería
# 8710                                   GB1      West Ham United Football Club
# 9029                                   ES1     Real Sociedad de Fútbol S.A.D.
# 9108                                   FR1                  AS Nancy-Lorraine
# ...                                    ...                                ...
# 32499                                  ES1  Unión Deportiva Las Palmas S.A.D.
# 32504                                  IT1                US Salernitana 1919
# 32507                                  GB1                         Luton Town
# 32521                                  GB1          Aston Villa Football Club
# 32526                                  FR1     Montpellier Hérault Sport Club
#
#       market_value_in_eur highest_market_value_in_eur
# 6946                  NaN                         NaN
# 6949                  NaN                         NaN
# 8710                  NaN                         NaN
# 9029                  NaN                         NaN
# 9108                  NaN                         NaN
# ...                   ...                         ...
# 32499                 NaN                         NaN
# 32504                 NaN                         NaN
# 32507                 NaN                         NaN
# 32521                 NaN                         NaN
# 32526                 NaN                         NaN
#
# [389 rows x 23 columns]

# %%
cur_players = players[players.last_season==2024]

# %%
cur_players.groupby(['country_league'])['current_club_id'].nunique()
# Out:
# country_league
# England    20
# France     18
# Germany    18
# Italy      20
# Spain      20
# Name: current_club_id, dtype: int64

# %%
cur_players.groupby(['country_league'])['player_id'].nunique()
# Out:
# country_league
# England    540
# France     473
# Germany    507
# Italy      568
# Spain      493
# Name: player_id, dtype: int64

# %%
cur_players.loc[:, 'playing_home'] = cur_players.country_of_citizenship==cur_players.country_league
# Out:
# C:\Users\kqtan\AppData\Local\Temp\ipykernel_25528\937123509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cur_players.loc[:, 'playing_home'] = cur_players.country_of_citizenship==cur_players.country_league

# %%
cur_players['foot'].value_counts()
# Out:
# foot
# right    1803
# left      671
# both       81
# Name: count, dtype: int64

# %% [markdown]
# # Analysis: Clubs

# %%
team_mv = cur_players.groupby(['current_club_id'])['market_value_in_eur'].sum()
team_mv = pd.DataFrame(team_mv).reset_index()

# %%
club_drop = [
    'total_market_value', 'coach_name'
]

team_mv = team_mv.rename({'market_value_in_eur': 'total_market_value'}, axis=1)
clubs_of_int = clubs_of_int.drop(club_drop, axis=1)
clubs_of_int = clubs_of_int.merge(team_mv, how='left', left_on='club_id', right_on='current_club_id').drop(['current_club_id'], axis=1)

# %%
clubs_of_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  173 non-null    int64
#  1   club_code                173 non-null    object
#  2   name                     173 non-null    object
#  3   domestic_competition_id  173 non-null    object
#  4   squad_size               173 non-null    int64
#  5   average_age              172 non-null    float64
#  6   foreigners_number        173 non-null    int64
#  7   foreigners_percentage    172 non-null    float64
#  8   national_team_players    173 non-null    int64
#  9   stadium_name             173 non-null    object
#  10  stadium_seats            173 non-null    int64
#  11  net_transfer_record      173 non-null    object
#  12  last_season              173 non-null    int64
#  13  filename                 173 non-null    object
#  14  url                      173 non-null    object
#  15  competition_id           173 non-null    object
#  16  competition_code         173 non-null    object
#  17  country_name             173 non-null    object
#  18  total_market_value       96 non-null     float64
#  19  net_transfer_sign        173 non-null    object
#  20  net_transfer_value       173 non-null    object
#  21  net_transfer_Mil         173 non-null    float64
# dtypes: float64(4), int64(6), object(12)
# memory usage: 29.9+ KB

# %%
clubs_of_int.to_parquet('cleaned_data/t5_league_clubs.parquet', index=False)
